# %% [markdown]
# <a href="https://colab.research.google.com/github/hanan99/Mobile-pricing/blob/main/Mobile-pricing-Exer2_P3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math

from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import seaborn as sns

# %%
def make_report(y_pred , y_true):
    print ("")
    print ("Classification Report: ")
    print (classification_report(y_true, y_pred))
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plot_confusion_matrix(conf_mat=cm)
    plt.show()

# %%
pd.set_option('display.max_columns', 50)
datapath = '/content/Dataset/mobile-price-classification/'

# %% [markdown]
# # New Section

# %%
data = pd.read_csv(datapath+'train.csv')
print(data.shape)
display(data.head())
display(data.info())
display(data.describe())
# Out:
# (2000, 21)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
# ...

# %%
null_data = data.isnull().sum().sort_values(ascending = False)
null_data = null_data[null_data>0]
null_data
# Out:
# Series([], dtype: int64)

# %%
for i in data.columns:
    try:
        sns.violinplot(y = data[i])
        plt.show()
        print(i)
    except:
        pass
# Out:
# battery_power
# blue
# clock_speed
# dual_sim
# fc
# four_g
# int_memory
# m_dep
# mobile_wt
# n_cores
# pc
# px_height
# px_width
# ram
# sc_h
# sc_w
# talk_time
# three_g
# touch_screen
# wifi
# price_range

# %%
plt.figure(figsize=(30,30))
correlationMatrix = data.corr()
sns.heatmap(correlationMatrix, annot=True)
plt.savefig(path+'corr.jpg')
plt.show()
print(correlationMatrix['price_range'].sort_values(ascending=False))
# Out:
# price_range      1.000000
# ram              0.917046
# battery_power    0.200723
# px_width         0.165818
# px_height        0.148858
# int_memory       0.044435
# sc_w             0.038711
# pc               0.033599
# three_g          0.023611
# sc_h             0.022986
# fc               0.021998
# talk_time        0.021859
# blue             0.020573
# wifi             0.018785
# dual_sim         0.017444
# four_g           0.014772
# n_cores          0.004399
# m_dep            0.000853
# clock_speed     -0.006606
# mobile_wt       -0.030302
# touch_screen    -0.030411
# Name: price_range, dtype: float64

# %% [markdown]
# # **Model**

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('price_range', axis=1), data['price_range'], test_size=0.30, random_state=42)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1400, 20)
# (1400,)
# (600, 20)
# (600,)

# %% [markdown]
#  **Question 1**

# %%
clf = make_pipeline(StandardScaler(),
                    LogisticRegression())
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
make_report(pred, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       151
#            1       0.91      0.97      0.94       146
#            2       0.99      0.91      0.95       148
#            3       0.96      0.99      0.98       155
#
#     accuracy                           0.96       600
#    macro avg       0.96      0.96      0.96       600
# weighted avg       0.96      0.96      0.96       600

# %% [markdown]
# **Question 2**

# %%
data['price_range'].hist()
plt.title('whole dataset')
plt.show()
y_train.hist()
plt.title('train dataset')
plt.show()
y_test.hist()
plt.title('test dataset')
plt.show()
